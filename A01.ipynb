# %% [markdown]
# # Multiplos de 3

# %%
multiplos_de_3 = []

for n in range(1, 101):  
    multiplo = n * 3      
    multiplos_de_3.append(multiplo) 
    
    print(multiplos_de_3)

len(multiplos_de_3)
# Out:
# [3]
# [3, 6]
# [3, 6, 9]
# [3, 6, 9, 12]
# [3, 6, 9, 12, 15]
# [3, 6, 9, 12, 15, 18]
# [3, 6, 9, 12, 15, 18, 21]
# [3, 6, 9, 12, 15, 18, 21, 24]
# [3, 6, 9, 12, 15, 18, 21, 24, 27]
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30]
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33]
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36]
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39]
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42]
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45]
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48]
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51]
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54]
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57]
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60]
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63]
# ...

# %% [markdown]
# # Datos PE

# %%
import pandas as pd
data = pd.read_excel("datosPE.xlsx")
data
# Out:
#     ID Persona  Peso  Estatura
# 0            1    67      1.41
# 1            2    99      1.83
# 2            3    86      1.90
# 3            4   118      1.65
# 4            5   109      1.67
# ..         ...   ...       ...
# 95          96    88      1.49
# 96          97    98      1.54
# 97          98    95      1.57
# 98          99    61      1.61
# 99         100   107      1.62
#
# [100 rows x 3 columns]

# %%
data.columns
# Out:
# Index(['ID Persona', 'Peso', 'Estatura'], dtype='object')

# %%
data ["Masa corporal"] = data["Peso"] % (data["Estatura"]**2)
data
# Out:
#     ID Persona  Peso  Estatura  Masa corporal
# 0            1    67      1.41         1.3927
# 1            2    99      1.83         1.8819
# 2            3    86      1.90         2.9700
# 3            4   118      1.65         0.9325
# 4            5   109      1.67         0.2329
# ..         ...   ...       ...            ...
# 95          96    88      1.49         1.4161
# 96          97    98      1.54         0.7644
# 97          98    95      1.57         1.3338
# 98          99    61      1.61         1.3817
# 99         100   107      1.62         2.0240
#
# [100 rows x 4 columns]

# %% [markdown]
# # Datos CT

# %%
import pandas as pd
data = pd.read_excel("datosCT.xlsx")
data
# Out:
#     Unnamed: 0  Ingreso  Gasto
# 0        Enero     1340   1880
# 1      Febrero     2590   3130
# 2        Marzo     3570   2140
# 3        Abril     4450   3370
# 4         Mayo     1330   2990
# 5        Junio     1610   1970
# 6        Julio     1500   2230
# 7       Agosto     2270   1240
# 8   Septiembre     1910   1470
# 9      Octubre     2120   2280
# 10   Noviembre     3950   1870
# 11   Diciembre     1380   3140

# %%
ingreso_neto = data["Ingreso"].sum() 
print(ingreso_neto)
# Out:
# 28020

# %%
gastos_totales = data["Gasto"].sum()
print(gastos_totales)
# Out:
# 27710

# %%
data ["Ingreso total"] = (ingreso_neto) - (gastos_totales)

# %%
data.at[12, "Ingreso total"] = data["Ingreso"].sum() - data["Gasto"].sum()
data
# Out:
#     Unnamed: 0  Ingreso   Gasto  Ingreso total
# 0        Enero   1340.0  1880.0          310.0
# 1      Febrero   2590.0  3130.0          310.0
# 2        Marzo   3570.0  2140.0          310.0
# 3        Abril   4450.0  3370.0          310.0
# 4         Mayo   1330.0  2990.0          310.0
# 5        Junio   1610.0  1970.0          310.0
# 6        Julio   1500.0  2230.0          310.0
# 7       Agosto   2270.0  1240.0          310.0
# 8   Septiembre   1910.0  1470.0          310.0
# 9      Octubre   2120.0  2280.0          310.0
# 10   Noviembre   3950.0  1870.0          310.0
# 11   Diciembre   1380.0  3140.0          310.0
# 12         NaN      NaN     NaN          310.0

# %%
resultado_df = pd.DataFrame({"Resultado": [ingreso_total]})
resultado_df.to_excel(nombre_archivo, index=False, startrow=11, startcol=4, engine='openpyxl')
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 resultado_df = pd.DataFrame({"Resultado": [ingreso_total]})
#       2 resultado_df.to_excel(nombre_archivo, index=False, startrow=11, startcol=4, engine='openpyxl')
#       3 data
#
# NameError: name 'ingreso_total' is not defined
